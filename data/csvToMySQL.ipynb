# %%
import pandas as pd

# %%
columns = [
    '번호','식품코드', '식품명','데이터구분코드','데이터구분명','품목대표/상용제품_코드','품목대표/상용제품','식품기원코드',
    '식품기원명', '식품대분류코드','식품대분류명', '대표식품코드', '대표식품명','식품중분류코드', '식품중분류명','식품소분류코드',
    '식품소분류명','식품세분류코드','식품세분류명', '영양성분함량기준량','에너지(kcal)','수분(g)','단백질(g)','지방(g)',
    '회분(g)','탄수화물(g)','당류(g)','식이섬유(g)', '칼슘(mg)','철(mg)','인(mg)','칼륨(mg)','나트륨(mg)','콜레스테롤(mg)','포화지방산(g)'
]
df = pd.read_csv('food_analysis/food_data_4.csv',usecols=columns)
df
# Out:
# C:\Users\OWNER\AppData\Local\Temp\ipykernel_11816\382827491.py:7: DtypeWarning: Columns (20,22,23,25,26,28,30,31,32,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('food_analysis/food_data_4.csv',usecols=columns)
#               번호                 식품코드          식품명 데이터구분코드 데이터구분명  \
# 0            1.0  D101-004160000-0001      국밥_돼지머리       D     음식
# 1            2.0  D101-004310000-0001      국밥_순대국밥       D     음식
# 2            3.0  D101-004500000-0001       국밥_콩나물       D     음식
# 3            4.0  D101-006000000-0001          기장밥       D     음식
# 4            5.0  D101-007000000-0001           김밥       D     음식
# ...          ...                  ...          ...     ...    ...
# 167332  167333.0  R318-020035700-0000   소금_천일염_토판염      R1   원재료성
# 167333  167334.0  R318-020035800-0000  소금_천일염_가는소금      R1   원재료성
# 167334  167335.0  R318-020045600-0000   소금_프랑스_소금꽃      R1   원재료성
# ...

# %%
df = df.rename(columns={
    '에너지(kcal)': '에너지_kcal',
    '수분(g)': '수분_g',
    '단백질(g)': '단백질_g',
    '지방(g)': '지방_g',
    '회분(g)': '회분_g',
    '탄수화물(g)': '탄수화물_g',
    '당류(g)': '당류_g',
    '식이섬유(g)': '식이섬유_g',
    '칼슘(mg)': '칼슘_mg',
    '철(mg)': '철_mg',
    '인(mg)': '인_mg',
    '칼륨(mg)': '칼륨_mg',
    '나트륨(mg)': '나트륨_mg',
    '콜레스테롤(mg)': '콜레스테롤_mg',
    '포화지방산(g)': '포화지방산_g',
        '품목대표/상용제품_코드': '품목대표상용제품코드',
    '품목대표/상용제품': '품목대표상용제품'
})

# %%
numeric_cols = ['에너지_kcal','수분_g','단백질_g','지방_g','회분_g',
                '탄수화물_g','당류_g','식이섬유_g','칼슘_mg','철_mg',
                '인_mg','칼륨_mg','나트륨_mg','콜레스테롤_mg','포화지방산_g']

for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
df = df.where(pd.notnull(df), None)

# %%
df.columns
# Out:
# Index(['번호', '식품코드', '식품명', '데이터구분코드', '데이터구분명', '품목대표상용제품코드', '품목대표상용제품',
#        '식품기원코드', '식품기원명', '식품대분류코드', '식품대분류명', '대표식품코드', '대표식품명', '식품중분류코드',
#        '식품중분류명', '식품소분류코드', '식품소분류명', '식품세분류코드', '식품세분류명', '영양성분함량기준량',
#        '에너지_kcal', '수분_g', '단백질_g', '지방_g', '회분_g', '탄수화물_g', '당류_g', '식이섬유_g',
#        '칼슘_mg', '철_mg', '인_mg', '칼륨_mg', '나트륨_mg', '콜레스테롤_mg', '포화지방산_g'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167337 entries, 0 to 167336
# Data columns (total 35 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   번호          167337 non-null  float64
#  1   식품코드        167337 non-null  object
#  2   식품명         167337 non-null  object
#  3   데이터구분코드     167337 non-null  object
#  4   데이터구분명      167337 non-null  object
#  5   품목대표상용제품코드  167337 non-null  float64
#  6   품목대표상용제품    167337 non-null  object
#  7   식품기원코드      167337 non-null  float64
#  8   식품기원명       167337 non-null  object
#  9   식품대분류코드     167337 non-null  float64
#  10  식품대분류명      167144 non-null  object
#  11  대표식품코드      167337 non-null  float64
#  12  대표식품명       167227 non-null  object
#  13  식품중분류코드     167335 non-null  float64
#  14  식품중분류명      167032 non-null  object
#  15  식품소분류코드     167335 non-null  float64
#  16  식품소분류명      166892 non-null  object
#  17  식품세분류코드     166549 non-null  float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167337 entries, 0 to 167336
# Data columns (total 35 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   번호          167337 non-null  float64
#  1   식품코드        167337 non-null  object
#  2   식품명         167337 non-null  object
#  3   데이터구분코드     167337 non-null  object
#  4   데이터구분명      167337 non-null  object
#  5   품목대표상용제품코드  167337 non-null  float64
#  6   품목대표상용제품    167337 non-null  object
#  7   식품기원코드      167337 non-null  float64
#  8   식품기원명       167337 non-null  object
#  9   식품대분류코드     167337 non-null  float64
#  10  식품대분류명      167144 non-null  object
#  11  대표식품코드      167337 non-null  float64
#  12  대표식품명       167227 non-null  object
#  13  식품중분류코드     167335 non-null  float64
#  14  식품중분류명      167032 non-null  object
#  15  식품소분류코드     167335 non-null  float64
#  16  식품소분류명      166892 non-null  object
#  17  식품세분류코드     166549 non-null  float64
# ...

# %%
df['식품명'] = df['식품명'].replace("_", " ", regex=True)
df
# Out:
#               번호                 식품코드          식품명 데이터구분코드 데이터구분명  품목대표상용제품코드  \
# 0            1.0  D101-004160000-0001      국밥 돼지머리       D     음식         1.0
# 1            2.0  D101-004310000-0001      국밥 순대국밥       D     음식         1.0
# 2            3.0  D101-004500000-0001       국밥 콩나물       D     음식         1.0
# 3            4.0  D101-006000000-0001          기장밥       D     음식         1.0
# 4            5.0  D101-007000000-0001           김밥       D     음식         1.0
# ...          ...                  ...          ...     ...    ...         ...
# 167332  167333.0  R318-020035700-0000   소금 천일염 토판염      R1   원재료성         1.0
# 167333  167334.0  R318-020035800-0000  소금 천일염 가는소금      R1   원재료성         1.0
# 167334  167335.0  R318-020045600-0000   소금 프랑스 소금꽃      R1   원재료성         1.0
# 167335  167336.0  R318-020045700-0000   소금 프랑스 토판염      R1   원재료성         1.0
# 167336  167337.0  R320-025030002-0000   팽창제 효모 말린것      R1   원재료성         1.0
#
# ...

# %%
df['데이터구분명'].unique()
# Out:
# array(['음식', '원재료성', '가공식품'], dtype=object)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+pymysql://root:1234@localhost:3306/sugarcare?charset=utf8mb4")

#df.to_sql(name='food_info', con=engine, if_exists='append', index=False)
df.to_sql(name='food_info', con=engine, if_exists='append', index=False)
# Out:
# 167337

# %%
df.describe()
# Out:
#                   번호   품목대표/상용제품_코드         식품기원코드        식품대분류코드  \
# count  167337.000000  167337.000000  167337.000000  167337.000000
# mean    83669.000000       1.945284       1.168630      10.796710
# std     48306.175335       0.232467       0.684395       8.402586
# min         1.000000       1.000000       1.000000       1.000000
# 25%     41835.000000       2.000000       1.000000       1.000000
# 50%     83669.000000       2.000000       1.000000       9.000000
# 75%    125503.000000       2.000000       1.000000      19.000000
# max    167337.000000       3.000000       8.000000      27.000000
#
#               대표식품코드       식품중분류코드       식품소분류코드        식품세분류코드        수분(g)  \
# count  167337.000000  1.673350e+05  1.673350e+05  166549.000000  9181.000000
# mean    11097.406103  1.083423e+06  1.083423e+08       0.254844    58.670046
# std      8428.420932  8.419774e+05  8.419774e+07       3.479459    30.234694
# ...
